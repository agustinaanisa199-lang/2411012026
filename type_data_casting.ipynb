# %% [markdown]
# <a href="https://colab.research.google.com/github/agustinaanisa199-lang/2411012026/blob/main/type_data_casting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = 'budi'
usia = 20
lajang = True

print(type(nama))
print(type(usia))
print(type(lajang))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>

# %%
usia = input('masukkan usia anda : ')
print(type(usia))
# Out:
# masukkan usia anda : 20
# <class 'str'>

# %%
panjang = input('masukkan panjang : ')
lebar = input('masukkan lebar : ')

print('luas =', panjang * lebar)
# Out:
# masukkan panjang : 60
# masukkan lebar : 54
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1091/1972580460.py in <cell line: 0>()
#       2 lebar = input('masukkan lebar : ')
#       3
# ----> 4 print('luas =', panjang * lebar)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
kata = 'jeruk ' * 5
print(kata)
print(type(kata))
# Out:
# jeruk jeruk jeruk jeruk jeruk
# <class 'str'>

# %%
panjang = int(input('masukkan panjang'))
lebar = int(input('masukkan lebar'))

print('luas=', panjang * lebar)
# Out:
# masukkan panjang20
# masukkan lebar7
# luas= 140

# %%
nama = 'uni'
tahun_lahir = 2006

print(nama + ' lahir di tahun ' + str(tahun_lahir))
# Out:
# uni lahir di tahun 2006
